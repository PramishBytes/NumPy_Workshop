# %%
import numpy as np
x = np.array([1,2,3,4])
print(x)
# Out:
# [1 2 3 4]

# %% [markdown]
#  What is Nympy?
#  NumPy is the fundamental package for scientific computing in Python.
#  NumPY is a Python library that provides a multidimensional array object, various derived objects.

# %% [markdown]
# NumPY vs Python List
#
# Advantages of using NumPy Arrays over Python List:
# -> consumes less memory
# -> fast as compared to the python list
# -> convenient to use

# %%
y= np.array([1,2,3,4,5,6,7,8])
print(y) #NumPy
# Out:
# [1 2 3 4 5 6 7 8]

# %%
y=[1,2,3,4,5,6,7]
print(y)  #List
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %% [markdown]
# Importance of NumPY in Python
# 1) wide variety of mathematical operations on arrays
# 2) It supplies an enormous library of high level mathematical function that operates on these arrays and matrices.
# 3) mathematical, logical, shape manipulation, sorting,selecting,I/O,discrete fourier transforms, basic linear algebra, basis simulation and much more.

# %% [markdown]
# Difference Between NumPy Array and List in Python
# 1) Data type storage
# 2) Importing module
# 3) Numerical operation
# 4) Modification capabilities
# 5) Consumes less memory
# 6) Fast as compared to python list
