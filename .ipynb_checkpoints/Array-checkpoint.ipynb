# %% [markdown]
# __ARRAY__
#
# __To create a NumPy array, you cna use the function np.array()__

# %%
import numpy as np 
a = np.array([1,2,3])
print(a)
# Out:
# [1 2 3]

# %%
x= [1,2,3,4,5]

y = np.array(x)
print(y)

print(type(y))
# Out:
# [1 2 3 4 5]
# <class 'numpy.ndarray'>

# %%
l = []

for i in range(1,5):
    int_1 = input("enter: ")
    l.append(int_1)

print(np.array(l))
# Out:
# enter:  1
# enter:  2
# enter:  3
# enter:  4
# 1
